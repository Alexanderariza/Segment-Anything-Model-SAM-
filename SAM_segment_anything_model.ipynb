# %% [markdown]
# Alexander Ariza 🧑🏻‍💻
# Sent4Cas
# Segmentación de construcciones con SAM

# %%
# %%capture
# !pip install segment-geospatial

# %%
import os
import leafmap
from samgeo import SamGeo, tms_to_geotiff

# %%
# Define variables
image = 'colombia_maptiler_area.tif'
result = 'results_maptiler.gpkg'

# Define the bounding box and zoom level
bbox = [-75.118032,9.718649,-75.114212,9.721853]
zoom = 20

# Define the TMS URL (MapTiler example)
tms_url = 'https://api.maptiler.com/maps/satellite/{z}/{x}/{y}.jpg?key=sfcMpHvW61zRJDeEy9Wb'

# Try converting TMS to GeoTIFF
try:
    print("Converting TMS to GeoTIFF...")
    tms_to_geotiff(output=image, bbox=bbox, zoom=zoom, source=tms_url, overwrite=True)
    print(f"GeoTIFF successfully created: {image}")
except Exception as e:
    print(f"An error occurred during TMS to GeoTIFF conversion: {e}")

# Initialize SamGeo with parameters
sam = SamGeo(
    checkpoint='sam_vit_h_4b8939.pth',  # Ruta al archivo del modelo
    model_type='vit_h',                 # Tipo de modelo
    device='cuda',                      # Dispositivo (puede ser 'cpu' o 'cuda')
    erosion_kernel=(3, 3),              # Parámetro de erosión para el procesamiento de imágenes
    mask_multiplier=255,                # Multiplicador para las máscaras
    sam_kwargs=None,
)

# Generate the segmentation and convert to GeoPackage
try:
    print("Generating segmentation...")
    sam.generate(image, 'segment_maptiler.tif')
    print("Segmented TIFF created: segment_maptiler.tif")

    print("Converting segmented TIFF to GeoPackage...")
    sam.tiff_to_gpkg('segment_maptiler.tif', result, simplify_tolerance=None)
    print(f"GeoPackage successfully created: {result}")
except Exception as e:
    print(f"An error occurred during segmentation or GeoPackage conversion: {e}")
# Out:
# Converting TMS to GeoTIFF...
# Downloaded image 001/130
# Downloaded image 002/130
# Downloaded image 003/130
# Downloaded image 004/130
# Downloaded image 005/130
# Downloaded image 006/130
# Downloaded image 007/130
# Downloaded image 008/130
# Downloaded image 009/130
# Downloaded image 010/130
# Downloaded image 011/130
# Downloaded image 012/130
# Downloaded image 013/130
# Downloaded image 014/130
# Downloaded image 015/130
# Downloaded image 016/130
# Downloaded image 017/130
# Downloaded image 018/130
# Downloaded image 019/130
# Downloaded image 020/130
# Downloaded image 021/130
# Downloaded image 022/130
# Downloaded image 023/130
# Downloaded image 024/130
# Downloaded image 025/130
# Downloaded image 026/130
# Downloaded image 027/130
# Downloaded image 028/130
# Downloaded image 029/130
# Downloaded image 030/130
# Downloaded image 031/130
# Downloaded image 032/130
# Downloaded image 033/130
# Downloaded image 034/130
# Downloaded image 035/130
# Downloaded image 036/130
# Downloaded image 037/130
# Downloaded image 038/130
# Downloaded image 039/130
# Downloaded image 040/130
# Downloaded image 041/130
# Downloaded image 042/130
# Downloaded image 043/130
# Downloaded image 044/130
# Downloaded image 045/130
# Downloaded image 046/130
# Downloaded image 047/130
# Downloaded image 048/130
# Downloaded image 049/130
# Downloaded image 050/130
# Downloaded image 051/130
# Downloaded image 052/130
# Downloaded image 053/130
# Downloaded image 054/130
# Downloaded image 055/130
# Downloaded image 056/130
# Downloaded image 057/130
# Downloaded image 058/130
# Downloaded image 059/130
# Downloaded image 060/130
# Downloaded image 061/130
# Downloaded image 062/130
# Downloaded image 063/130
# Downloaded image 064/130
# Downloaded image 065/130
# Downloaded image 066/130
# Downloaded image 067/130
# Downloaded image 068/130
# Downloaded image 069/130
# Downloaded image 070/130
# Downloaded image 071/130
# Downloaded image 072/130
# Downloaded image 073/130
# Downloaded image 074/130
# Downloaded image 075/130
# Downloaded image 076/130
# Downloaded image 077/130
# Downloaded image 078/130
# Downloaded image 079/130
# Downloaded image 080/130
# Downloaded image 081/130
# Downloaded image 082/130
# Downloaded image 083/130
# Downloaded image 084/130
# Downloaded image 085/130
# Downloaded image 086/130
# Downloaded image 087/130
# Downloaded image 088/130
# Downloaded image 089/130
# Downloaded image 090/130
# Downloaded image 091/130
# Downloaded image 092/130
# Downloaded image 093/130
# Downloaded image 094/130
# Downloaded image 095/130
# Downloaded image 096/130
# Downloaded image 097/130
# Downloaded image 098/130
# Downloaded image 099/130
# Downloaded image 100/130
# Downloaded image 101/130
# Downloaded image 102/130
# Downloaded image 103/130
# Downloaded image 104/130
# Downloaded image 105/130
# Downloaded image 106/130
# Downloaded image 107/130
# Downloaded image 108/130
# Downloaded image 109/130
# Downloaded image 110/130
# Downloaded image 111/130
# Downloaded image 112/130
# Downloaded image 113/130
# Downloaded image 114/130
# Downloaded image 115/130
# Downloaded image 116/130
# Downloaded image 117/130
# Downloaded image 118/130
# Downloaded image 119/130
# Downloaded image 120/130
# Downloaded image 121/130
# Downloaded image 122/130
# Downloaded image 123/130
# Downloaded image 124/130
# Downloaded image 125/130
# Downloaded image 126/130
# Downloaded image 127/130
# Downloaded image 128/130
# Downloaded image 129/130
# Downloaded image 130/130
# Saving GeoTIFF. Please wait...
# Image saved to colombia_maptiler_area.tif
# GeoTIFF successfully created: colombia_maptiler_area.tif
# Generating segmentation...
# An error occurred during segmentation or GeoPackage conversion: CUDA out of memory. Tried to allocate 19.76 GiB. GPU

# %%
m = leafmap.Map()
m.add_raster(image)

style = {'color': '#3388ff', 'weight': 2, 'fillColor': '#7c4185', 'fillOpacity': 0.5}
m.add_vector(result, style=style)
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…
